# %%
# Load env variables

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Create an API client

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
# Creating helper functions

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }
    
    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Write a Python functions that checks a string for duplicate characters")

# Get Claude's response
answer = chat(messages)

print(answer)
# Out:
# ## Duplicate Character Checker
#
# Here are several Python functions to check for duplicate characters in a string:
#
# ```python
# def has_duplicates(string: str) -> bool:
#     """Check if a string contains any duplicate characters."""
#     return len(string) != len(set(string))
#
#
# def find_duplicates(string: str) -> set:
#     """Return a set of duplicate characters found in the string."""
#     seen = set()
#     duplicates = set()
#
#     for char in string:
#         if char in seen:
#             duplicates.add(char)
#         else:
#             seen.add(char)
#
#     return duplicates
#
#
# def count_duplicates(string: str) -> dict:
#     """Return a dictionary with duplicate characters and their counts."""
#     char_count = {}
#
#     for char in string:
#         char_count[char] = char_count.get(char, 0) + 1
#
#     return {char: count for char, count in char_count.items() if count > 1}
#
#
# def find_duplicate_positions(string: str) -> dict:
# ...

# %%
# Start with an empty message list
messages = []

# With my system prompt
# system = """
# You are a high-skilled senior Python developer.
# Choose the most efficient solution and explain why.
# Be concise and direct in your answer.
# """

# With the solution system prompt
system = """
You are a Python engineer who writes very concise code
"""

# Add the initial user question
add_user_message(messages, "Write a Python functions that checks a string for duplicate characters")

# Get Claude's response
answer = chat(messages, system=system)

print(answer)
# Out:
# ```python
# def has_duplicates(s: str) -> bool:
#     return len(s) != len(set(s))
# ```
#
# **Example usage:**
# ```python
# print(has_duplicates("hello"))   # True  ('l' appears twice)
# print(has_duplicates("world"))   # False
# print(has_duplicates("python"))  # False
# ```
#
# If you also want to **identify which characters are duplicated**:
#
# ```python
# def find_duplicates(s: str) -> set:
#     seen = set()
#     return {c for c in s if c in seen or seen.add(c)}
#
# print(find_duplicates("hello world"))  # {'l', 'o'}
# ```
